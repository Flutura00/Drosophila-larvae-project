# %%
from Drosophila_project.Speed_calculation_functions import *

# %%
# real_monkey_dots_open_loop
# gray_four_directions_open_loop
path_data = r"Z:\Freely swimming larvae\Erze\gray_four_directions_open_loop_2_min_0_015\combined_data.hdf5"
key1 = "all_freely_swimming_tracking_data_pandas"
df = pd.read_hdf(path_data, key1)
df.reset_index(inplace=True)
df = df_subset(df,lower_bound = 120,upper_bound = 240)

# %%
# Per krahasim te te dhenave, the njona kuti e shtin file 1
path_data = r"Z:\Freely swimming larvae\Erze\gray_four_directions_open_loop_2_min_0_07\combined_data.hdf5"
key1 = "all_freely_swimming_tracking_data_pandas"
df = pd.read_hdf(path_data, key1)
df.reset_index(inplace=True)
df = df_subset(df,lower_bound = 120,upper_bound = 240)
speed = calculate_speed_lists(df)
speed_2 = []
for ls in speed:
    ls = [x for x in ls if x <= 0.05]
    speed_2.append(ls)
bins_count_stimuli, pdf_gray_0_07, pdf_stimuli_0_07 = plot_data(speed = speed_2, title = " Probability distribution function DOTS, speed 4.2 mm/s",experiment_speed = "0_07",time_set = 10,exp_condition = "sine_waves")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['radius'] = r
# C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['radius'] = r
# C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# ...

# %%
#qetu file tjeter
path_data = r"Z:\Freely swimming larvae\Erze\gray_four_directions_open_loop_speed_0_035\combined_data.hdf5"
key1 = "all_freely_swimming_tracking_data_pandas"
df = pd.read_hdf(path_data, key1)
df.reset_index(inplace=True)

df = pd.read_hdf(path_data, key1)
df.reset_index(inplace=True)
df = df_subset(df,lower_bound = 10,upper_bound = 60)
speed = calculate_speed_lists(df)
speed_3 = []
for ls in speed:
    ls = [x for x in ls if x <= 0.05]
    speed_3.append(ls)
bins_count_stimuli, pdf_gray_0_035, pdf_stimuli_0_035 = plot_data(speed = speed_3, title = " Probability distribution function DOTS, speed 2.1 mm/s",experiment_speed = "0_035",time_set = 10,exp_condition = "sine_waves")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['radius'] = r
# C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['radius'] = r
# C:\Users\ag-bahl\PycharmProjects\Drosophila_project\speed_calculation_functions.py:23: SettingWithCopyWarning:
# ...

# %%
plt.plot(bins_count_stimuli[1:], pdf_gray_0_07, color = "blue", label = "4.1 mm/s")
plt.plot(bins_count_stimuli[1:], pdf_gray_0_035, color = "red", label = "2.1 mm/s")

plt.scatter(bins_count_stimuli[1:], pdf_gray_0_07, color = "blue",)
plt.scatter(bins_count_stimuli[1:], pdf_gray_0_035, color = "red")

plt.ylabel("Probability distribution", size = 15)
plt.xlabel("speed", size= 15)
plt.title("Probability distribution function of speed for ", size = 15)
plt.legend()
plt.show()
